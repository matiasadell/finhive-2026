# %% [markdown]
# # Install
#
# **Run this first, once per session**, then run whatever you came for. The agent notebooks import
# `langchain_openai`, so without this even `%run ../llm/gateway` fails with `ModuleNotFoundError`.
#
# `restartPython` clears the Python process, which is why this is a notebook of its own rather than a
# cell inside `llm/gateway`: a `%pip` there would reset the namespace of every notebook that `%run`
# it, mid-run.
#
# The pins live in `requirements.txt` next to this file, and that is the list to copy into a job's
# environment spec when there is a job (`agent-design.md` §22 item 8).

# %%
# %pip install -r ./requirements.txt

# %%
dbutils.library.restartPython()

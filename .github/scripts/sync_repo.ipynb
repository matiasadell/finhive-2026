# %%
import subprocess

repo_path = "/Workspace/Shared/finhive-2026"

print(f"Pulling {repo_path}...")
result = subprocess.run(
    ["git", "pull"],
    cwd=repo_path,
    capture_output=True,
    text=True,
)
